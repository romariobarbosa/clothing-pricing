# %%
#import libraries
import pandas as pd
import requests
import sqlite3
import re

from bs4        import BeautifulSoup
from datetime   import datetime
from sqlalchemy import create_engine

# %% [markdown]
# ## Classics

# %%
#API requests
url = 'http://books.toscrape.com/catalogue/category/books/classics_6'

headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}

page = requests.get(url, headers=headers)

#Beautiful Soup Objects
soup = BeautifulSoup(page.text, 'html.parser')

books_classic = soup.find('ol', class_='row')

books_classic_list = books_classic.find_all('article', class_='product_pod')
#books_classic_list[0]


# ============= Scraping Name, Price, Availability ============== #

classic_attributes = [list(filter(None, p.get_text().split('\n'))) for p in books_classic_list]

book_classic_table = pd.DataFrame(classic_attributes)

book_classic_table.columns = ['Name', 'Price', 'del1', 'Availability', 'del2', 'del3']
book_classic_table = book_classic_table.drop(['del1', 'del2', 'del3'], axis=1)
#regex = '(\d+\.\d+)'
#book_classic_table['Price'] = book_classic_table['Price'].apply(lambda x: re.search(regex, x).group(1))
book_classic_table['Price'] = book_classic_table['Price'].apply(lambda x: x[2:])

# ============= Scraping Star-Rating ================== #

classic_rating = [list(p.find('p', class_='star-rating').get('class')) for p in books_classic_list]
classic_rating = pd.DataFrame(classic_rating, columns=['del1', 'Star Rating'])
classic_rating = classic_rating.drop('del1', axis=1)

# ============= Table Concat ============== #

book_classic_table = pd.concat([book_classic_table, classic_rating], axis=1)

# ============= Insert Datetime Scrapy Column ============== #
book_classic_table['Scrapy Datetime'] = datetime.now().strftime('%Y-%m-%d- %H:%M:%S')
book_classic_table['Catalog'] = 'Classics'

book_classic_table
# Out:
#                                 Name  Price      Availability Star Rating  \
# 0                  The Secret Garden  15.08          In stock        Four
# 1                  The Metamorphosis  28.58          In stock         One
# 2             The Pilgrim's Progress  50.26          In stock         Two
# 3               The Hound of the ...  14.82          In stock         Two
# 4     Little Women (Little Women ...  28.07          In stock        Four
# 5                 Gone with the Wind  32.49          In stock       Three
# 6                            Candide  58.63          In stock       Three
# 7                        Animal Farm  57.22          In stock       Three
# 8                  Wuthering Heights  17.73          In stock       Three
# 9          The Picture of Dorian ...  29.70          In stock         Two
# 10      The Complete Stories and ...  26.78          In stock        Four
# 11                           Beowulf  38.35          In stock         Two
# 12           And Then There Were ...  35.01          In stock         Two
# 13             The Story of Hong ...  43.19          In stock        Four
# 14                 The Little Prince  45.42          In stock         Two
# 15             Sense and Sensibility  37.46          In stock         One
# 16                   Of Mice and Men  47.11          In stock         Two
# 17                              Emma  32.93          In stock         Two
# 18  Alice in Wonderland (Alice's ...  55.53          In stock         One
#
#          Scrapy Datetime   Catalog
# 0   2021-07-07- 15:21:00  Classics
# 1   2021-07-07- 15:21:00  Classics
# 2   2021-07-07- 15:21:00  Classics
# 3   2021-07-07- 15:21:00  Classics
# 4   2021-07-07- 15:21:00  Classics
# 5   2021-07-07- 15:21:00  Classics
# 6   2021-07-07- 15:21:00  Classics
# 7   2021-07-07- 15:21:00  Classics
# 8   2021-07-07- 15:21:00  Classics
# 9   2021-07-07- 15:21:00  Classics
# 10  2021-07-07- 15:21:00  Classics
# 11  2021-07-07- 15:21:00  Classics
# 12  2021-07-07- 15:21:00  Classics
# 13  2021-07-07- 15:21:00  Classics
# 14  2021-07-07- 15:21:00  Classics
# 15  2021-07-07- 15:21:00  Classics
# 16  2021-07-07- 15:21:00  Classics
# 17  2021-07-07- 15:21:00  Classics
# 18  2021-07-07- 15:21:00  Classics

# %% [markdown]
# ## Science Fiction

# %%
#API Requests
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}

url = 'https://books.toscrape.com/catalogue/category/books/science-fiction_16'

page = requests.get(url, headers=headers)

#Beautiful Soup Objects
soup = BeautifulSoup(page.text, 'html.parser')

books_sf = soup.find('ol', class_='row')

books_sf_list = books_sf.find_all('article', class_='product_pod')
#books_sf_list[0]

# ============= Scraping Name, Price, Availability ============== #

sf_attributes = [list(filter(None, p.get_text().split('\n'))) for p in books_sf_list]

book_sf_table = pd.DataFrame(sf_attributes)
book_sf_table.columns = ['Name', 'Price', 'del1', 'Availability', 'del2', 'del3']
book_sf_table = book_sf_table.drop(['del1', 'del2', 'del3'], axis=1)
book_sf_table['Price'] = book_sf_table['Price'].apply(lambda x: x[2:])
#book_sf_table

# ============= Scraping Star-Rating ================== #

sf_rating = [list(p.find('p', class_='star-rating').get('class')) for p in books_sf_list]
sf_rating = pd.DataFrame(sf_rating, columns=['del1', 'Star Rating'])
sf_rating = sf_rating.drop('del1', axis=1)

# ============= Table Concat ============== #

book_sf_table = pd.concat([book_sf_table, sf_rating], axis=1)

# ============= Insert Datetime Scrapy Column ============== #
book_sf_table['Scrapy Datetime'] = datetime.now().strftime('%Y-%m-%d- %H:%M:%S')
book_sf_table['Catalog'] = 'Science Fiction'

book_sf_table
# Out:
#                                               Name  Price      Availability  \
# 0                  Mesaerion: The Best Science ...  37.59          In stock
# 1                                             Join  35.67          In stock
# 2             William Shakespeare's Star Wars: ...  43.30          In stock
# 3                                      The Project  10.65          In stock
# 4                                  Soft Apocalypse  26.12          In stock
# 5                Sleeping Giants (Themis Files ...  48.74          In stock
# 6                                            Arena  21.36          In stock
# 7   Foundation (Foundation (Publication Order) ...  32.42          In stock
# 8                        The Restaurant at the ...  10.92          In stock
# 9                                 Ready Player One  19.07          In stock
# 10                      Life, the Universe and ...  33.26          In stock
# 11                                  Dune (Dune #1)  54.86          In stock
# 12                        Do Androids Dream of ...  51.48          In stock
# 13                      Three Wishes (River of ...  44.18          In stock
# 14                          The Last Girl (The ...  36.26          In stock
# 15                 Having the Barbarian's Baby ...  34.96          In stock
#
#    Star Rating       Scrapy Datetime          Catalog
# 0          One  2021-07-07- 15:24:50  Science Fiction
# 1         Five  2021-07-07- 15:24:50  Science Fiction
# 2         Four  2021-07-07- 15:24:50  Science Fiction
# 3          One  2021-07-07- 15:24:50  Science Fiction
# 4          Two  2021-07-07- 15:24:50  Science Fiction
# 5          One  2021-07-07- 15:24:50  Science Fiction
# 6         Four  2021-07-07- 15:24:50  Science Fiction
# 7          One  2021-07-07- 15:24:50  Science Fiction
# 8          One  2021-07-07- 15:24:50  Science Fiction
# 9         Four  2021-07-07- 15:24:50  Science Fiction
# 10         Two  2021-07-07- 15:24:50  Science Fiction
# 11         One  2021-07-07- 15:24:50  Science Fiction
# 12         One  2021-07-07- 15:24:50  Science Fiction
# 13         Two  2021-07-07- 15:24:50  Science Fiction
# 14         Two  2021-07-07- 15:24:50  Science Fiction
# 15        Four  2021-07-07- 15:24:50  Science Fiction

# %% [markdown]
# ## Humor

# %%
#API Requests
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}

url = 'https://books.toscrape.com/catalogue/category/books/humor_30'

page = requests.get(url, headers=headers)

#Beautiful Soup Objects
soup = BeautifulSoup(page.text, 'html.parser')

books_humor = soup.find('ol', class_='row')

books_humor_list = books_humor.find_all('article', class_='product_pod')
#books_sf_list[0]

# ============= Scraping Name, Price, Availability ============== #

humor_attributes = [list(filter(None, p.get_text().split('\n'))) for p in books_humor_list]

book_humor_table = pd.DataFrame(humor_attributes)
book_humor_table.columns = ['Name', 'Price', 'del1', 'Availability', 'del2', 'del3']
book_humor_table = book_humor_table.drop(['del1', 'del2', 'del3'], axis=1)
book_humor_table['Price'] = book_humor_table['Price'].apply(lambda x: x[2:])
#book_humor_table

# ============= Scraping Star-Rating ================== #

humor_rating = [list(p.find('p', class_='star-rating').get('class')) for p in books_humor_list]
humor_rating = pd.DataFrame(humor_rating, columns=['del1', 'Star Rating'])
humor_rating = humor_rating.drop('del1', axis=1)

# ============= Table Concat ============== #

book_humor_table = pd.concat([book_humor_table, humor_rating], axis=1)

# ============= Insert Datetime Scrapy Column ============== #
book_humor_table['Scrapy Datetime'] = datetime.now().strftime('%Y-%m-%d- %H:%M:%S')
book_humor_table['Catalog'] = 'Humor'

book_humor_table
# Out:
#                               Name  Price      Availability Star Rating  \
# 0         The Long Haul (Diary ...  44.07          In stock         One
# 1         Old School (Diary of ...  11.83          In stock        Five
# 2              I Know What I'm ...  25.98          In stock        Four
# 3        Hyperbole and a Half: ...  14.75          In stock        Five
# 4         Dress Your Family in ...  43.68          In stock       Three
# 5  Toddlers Are A**holes: It's ...  25.55          In stock         One
# 6        When You Are Engulfed ...  30.89          In stock        Five
# 7                            Naked  31.69          In stock       Three
# 8   Lamb: The Gospel According ...  55.50          In stock        Five
# 9                  Holidays on Ice  51.07          In stock         Two
#
#         Scrapy Datetime Catalog
# 0  2021-07-07- 15:24:55   Humor
# 1  2021-07-07- 15:24:55   Humor
# 2  2021-07-07- 15:24:55   Humor
# 3  2021-07-07- 15:24:55   Humor
# 4  2021-07-07- 15:24:55   Humor
# 5  2021-07-07- 15:24:55   Humor
# 6  2021-07-07- 15:24:55   Humor
# 7  2021-07-07- 15:24:55   Humor
# 8  2021-07-07- 15:24:55   Humor
# 9  2021-07-07- 15:24:55   Humor

# %% [markdown]
# ## Business

# %%
#API Requests
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}

url = 'https://books.toscrape.com/catalogue/category/books/business_35'

page = requests.get(url, headers=headers)

#Beautiful Soup Objects
soup = BeautifulSoup(page.text, 'html.parser')

books_business = soup.find('ol', class_='row')

books_business_list = books_business.find_all('article', class_='product_pod')
books_business_list[0]

# ============= Scraping Name, Price, Availability ============== #

business_attributes = [list(filter(None, p.get_text().split('\n'))) for p in books_business_list]

book_business_table = pd.DataFrame(business_attributes)
book_business_table.columns = ['Name', 'Price', 'del1', 'Availability', 'del2', 'del3']
book_business_table = book_business_table.drop(['del1', 'del2', 'del3'], axis=1)
book_business_table['Price'] = book_business_table['Price'].apply(lambda x: x[2:])
#book_humor_table

# ============= Scraping Star-Rating ================== #

business_rating = [list(p.find('p', class_='star-rating').get('class')) for p in books_business_list]
business_rating = pd.DataFrame(business_rating, columns=['del1', 'Star Rating'])
business_rating = business_rating.drop('del1', axis=1)

# ============= Table Concat ============== #

book_business_table = pd.concat([book_business_table, business_rating], axis=1)

# ============= Insert Datetime Scrapy Column ============== #
book_business_table['Scrapy Datetime'] = datetime.now().strftime('%Y-%m-%d- %H:%M:%S')
book_business_table['Catalog'] = 'Business'

book_business_table
# Out:
#                               Name  Price      Availability Star Rating  \
# 0     The Dirty Little Secrets ...  33.34          In stock        Four
# 1           The Third Wave: An ...  12.61          In stock        Five
# 2   The 10% Entrepreneur: Live ...  27.55          In stock       Three
# 3           Shoe Dog: A Memoir ...  23.99          In stock         Two
# 4           Made to Stick: Why ...  38.85          In stock        Five
# 5      Quench Your Own Thirst: ...  43.14          In stock         One
# 6           The Art of Startup ...  21.00          In stock       Three
# 7           Born for This: How ...  21.59          In stock        Five
# 8    The E-Myth Revisited: Why ...  36.91          In stock         One
# 9               Rich Dad, Poor Dad  51.74          In stock         One
# 10       The Lean Startup: How ...  33.92          In stock       Three
# 11                          Rework  44.88          In stock         Two
#
#          Scrapy Datetime   Catalog
# 0   2021-07-07- 15:25:03  Business
# 1   2021-07-07- 15:25:03  Business
# 2   2021-07-07- 15:25:03  Business
# 3   2021-07-07- 15:25:03  Business
# 4   2021-07-07- 15:25:03  Business
# 5   2021-07-07- 15:25:03  Business
# 6   2021-07-07- 15:25:03  Business
# 7   2021-07-07- 15:25:03  Business
# 8   2021-07-07- 15:25:03  Business
# 9   2021-07-07- 15:25:03  Business
# 10  2021-07-07- 15:25:03  Business
# 11  2021-07-07- 15:25:03  Business

# %% [markdown]
# ## Complete Catalog

# %%
book_catalog = pd.concat([book_classic_table, book_sf_table, book_humor_table, book_business_table], axis=0)
book_catalog.columns = ['name', 'price', 'availability', 'rating', 'datetime', 'catalog']
book_catalog.head()
# Out:
#                              name  price      availability rating  \
# 0               The Secret Garden  15.08          In stock   Four
# 1               The Metamorphosis  28.58          In stock    One
# 2          The Pilgrim's Progress  50.26          In stock    Two
# 3            The Hound of the ...  14.82          In stock    Two
# 4  Little Women (Little Women ...  28.07          In stock   Four
#
#                datetime   catalog
# 0  2021-07-07- 15:21:00  Classics
# 1  2021-07-07- 15:21:00  Classics
# 2  2021-07-07- 15:21:00  Classics
# 3  2021-07-07- 15:21:00  Classics
# 4  2021-07-07- 15:21:00  Classics

# %%
book_catalog.to_csv('book catalog')

# %%
query_books_schema = """
    CREATE TABLE books (
        name             TEXT,
        price            REAL,
        availability     TEXT,
        rating           TEXT,
        datetime         TEXT,
        catalog          TEXT    
    )
"""

# %%
conn = sqlite3.connect('book_catalog.sqlite')
cursor = conn.execute(query_books_schema)
conn.commit()
conn.close()

# %%
conn = create_engine('sqlite:///book_catalog.sqlite', echo=False)

# %%
book_catalog.to_sql('books', con=conn, if_exists='append', index=False)

# %%
query = """
    SELECT * FROM books WHERE catalog = 'Humor'
"""

df = pd.read_sql_query(query, conn)
df
# Out:
#                               name  price      availability rating  \
# 0         The Long Haul (Diary ...  44.07          In stock    One
# 1         Old School (Diary of ...  11.83          In stock   Five
# 2              I Know What I'm ...  25.98          In stock   Four
# 3        Hyperbole and a Half: ...  14.75          In stock   Five
# 4         Dress Your Family in ...  43.68          In stock  Three
# 5  Toddlers Are A**holes: It's ...  25.55          In stock    One
# 6        When You Are Engulfed ...  30.89          In stock   Five
# 7                            Naked  31.69          In stock  Three
# 8   Lamb: The Gospel According ...  55.50          In stock   Five
# 9                  Holidays on Ice  51.07          In stock    Two
#
#                datetime catalog
# 0  2021-07-07- 15:24:55   Humor
# 1  2021-07-07- 15:24:55   Humor
# 2  2021-07-07- 15:24:55   Humor
# 3  2021-07-07- 15:24:55   Humor
# 4  2021-07-07- 15:24:55   Humor
# 5  2021-07-07- 15:24:55   Humor
# 6  2021-07-07- 15:24:55   Humor
# 7  2021-07-07- 15:24:55   Humor
# 8  2021-07-07- 15:24:55   Humor
# 9  2021-07-07- 15:24:55   Humor
